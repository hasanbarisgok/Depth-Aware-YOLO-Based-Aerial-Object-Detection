# %% [markdown]
# # AOD4 Colab Training Notebook
#
# This notebook is prepared to extract `project.zip` from Google Drive and run YOLOv8 training on a Colab GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls "/content/drive/MyDrive"
# !ls "/content/drive/MyDrive/AOD4"

# %% [markdown]
# If your zip file is stored in a different folder, update the path below.

# %%
# %cd /content
# !rm -rf /content/project
# !unzip -q "/content/drive/MyDrive/AOD4/project.zip"
# !ls /content
# !ls /content/project

# %%
# %cd /content/project
# !pip install -r requirements.txt

# %%
import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
else:
    print('No GPU detected. Go to Runtime > Change runtime type and select a GPU.')

# %% [markdown]
# First, run a short 5-epoch speed test.

# %%
# %cd /content/project
# !python scripts/train_yolo.py --epochs 5 --batch 16 --imgsz 640 --device 0 --project runs --name speed_test

# %% [markdown]
# If the 5-epoch result looks good, start the 50-epoch training run.

# %%
# %cd /content/project
# !python scripts/train_yolo.py --epochs 50 --batch 16 --imgsz 640 --device 0 --project runs --name aod4_colab

# %%
# !ls /content/project/runs
# !find /content/project/runs -maxdepth 3 -type f | tail -n 30

# %% [markdown]
# Copy the results to Google Drive.

# %%
# !mkdir -p "/content/drive/MyDrive/AOD4/results"
# !cp -r /content/project/runs "/content/drive/MyDrive/AOD4/results/"
# !echo "Results copied to Drive"

# %% [markdown]
# You can also run single-image inference after training.

# %%
# Example usage:
# !python scripts/detect_image.py --image "/content/project/dataset/images/test/example.jpg" --weights "/content/project/runs/aod4_colab/weights/best.pt"
